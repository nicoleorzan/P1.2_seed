# %%
# %matplotlib inline
import numpy as np
from pylab import *
import matplotlib as mpl
import matplotlib.pyplot as plt
#mpl.rcParams['figure.dpi']= 200

# %%
import numpy as np
import matplotlib.pyplot as plt

dataorig = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/No blocks/Cachemiss/cleanmiss1024m') as datafile:
        for line in datafile:
            dataorig.append(float(line))
            
dataorig1 = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/No blocks/Cachemiss/cleanmiss2048m') as datafile:
        for line in datafile:
            dataorig1.append(float(line))


dataorig2 = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/No blocks/Cachemiss/cleanmiss4096m') as datafile:
        for line in datafile:
            dataorig2.append(float(line))

data1024miss = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/1024/Cachemiss/medie.txt') as datafileerr:
        for line in datafileerr:
            data1024miss.append(float(line)) 
            
data1024err = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/1024/Cachemiss/err.txt') as datafileerr:
        for line in datafileerr:
            data1024err.append(float(line)) 
            
    
            
data2048miss = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/1024/Cachemiss/medie.txt') as datafile:
        for line in datafile:
            data2048miss.append(float(line))

data2048err = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/2048/Cachemiss/err.txt') as datafileerr:
        for line in datafileerr:
            data2048err.append(float(line)) 
            
data4096miss = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/1024/Cachemiss/medie.txt') as datafile:
        for line in datafile:
            data4096miss.append(float(line))
            
data4096err = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/4096/Cachemiss/err.txt') as datafileerr:
        for line in datafileerr:
            data4096err.append(float(line)) 

mean1024 = 2088347.0
mean2048 = 7848320.16667
mean4096 = 25516493.5833
err1024 = 0.0005
err2048 = 0.0004
err4096 = 0.0021


fig, ax = plt.subplots(figsize=(7, 4))
plt.legend(bbox_to_anchor=(0.5, 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
x=np.array([1,2,4,8,16,32,64,128,256,512,1024])
ax.errorbar(x, data4096miss, yerr=data4096err, fmt='-o', label='fast transpose',color="darkviolet")
ax.set_title('MATRIX DIMENSION: 4096')
plt.xlabel('Block Dimensions')
plt.ylabel('Cache miss')
#ax.plot(x,data,'r')
ax.axhline(y = mean4096,label='original code',color="violet")
plt.legend()
#plt.xticks([1,2,4,8,16,32,64,128,256,512,1024])
#plt.yticks(data)


plt.show()

# %%
dataorig
# Out:
# [2109924.0,
#  2038984.0,
#  2117180.0,
#  2106645.0,
#  2105104.0,
#  2079800.0,
#  2045369.0,
#  2103193.0,
#  2105950.0,
#  2077478.0,
#  2080809.0,
#  2089728.0]

# %%
plt.legend(bbox_to_anchor=(0.5, 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
x=np.array([1,2,4,8,16,32,64,128,256,512,1024])
plt.xlabel('Block dimension')
plt.ylabel('Cache misses')
plt.title('FAST TRANSPOSE')
#plt.plot(x,data1024miss, label='fast transpose') 
#ax.errorbar(x, data, yerr=xerr, fmt='-o', label='fast transpose',color="darkblue")

plt.axhline(y = mean1024, label='original code')
#plt.axhline(y = mean2048)
#plt.axhline(y = mean4096)
marker_style = dict(linestyle=':', color='cornflowerblue', markersize=2)
#plt.plot(data1, 'red',  label='2048',**marker_style)
plt.plot(x,data1024miss, 'darkblue',  label='fast transpose',markersize=10)
#plt.plot(data2, 'darkviolet', label='4096',marker='$...$', markersize=4)
#plt.xticks([1,2,4,8,16,32,64,128,256,512,1024])
#plt.legend(('1024', '2048', '4096'))
plt.legend()
plt.show()
