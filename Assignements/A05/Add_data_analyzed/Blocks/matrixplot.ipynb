# %%
# %matplotlib inline
import numpy as np
from pylab import *
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi']= 200

# %%
import numpy as np
import matplotlib.pyplot as plt

data = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/1024/medie.txt') as datafile:
        for line in datafile:
            data.append(float(line))
xerr = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/1024/err.txt') as datafileerr:
        for line in datafileerr:
            xerr.append(float(line)) 
            
    
data1 = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/2048/medie.txt') as datafile:
        for line in datafile:
            data1.append(float(line))
            
xerr1 = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/2048/err.txt') as datafile:
        for line in datafile:
            xerr1.append(float(line))
                             
data2 = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/4096/medie.txt') as datafile:
        for line in datafile:
            data2.append(float(line))
            
xerr2 = []
with open('/home/nicole/Data Science/HPC/Transpose (ass4)/Blocks/4096/err.txt') as datafile:
        for line in datafile:
            xerr2.append(float(line))


mean=0.
n=0.
with open('/home/nicole/P1.2_seed/D5-exercise/code_provided/medianoblocks.txt') as datafile:
        for line in datafile:
            mean+=float(line)
            n+=1.
mean=mean/n
mean


data
mean1024 = 0.022
mean2048 = 0.11
mean4096 = 0.42
err1024 = 0.0005
err2048 = 0.0004
err4096 = 0.0021


#fig, (ax0, ax1) = plt.subplo2ts(figsize=(7, 4))#2, sharex=True)
fig, ax = plt.subplots(figsize=(7, 4))
plt.legend(bbox_to_anchor=(0.5, 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
x=np.array([1,2,4,8,16,32,64,128,256,512,1024])
ax.errorbar(x, data2, yerr=xerr2, fmt='-o', label='fast transpose',color="darkviolet")
ax.set_title('MATRIX DIMENSION: 4096')
plt.xlabel('Block Dimensions')
plt.ylabel('Time (s)')
#ax.plot(x,data,'r')
ax.axhline(y = mean4096,label='original code',color="violet")
plt.legend()
#plt.xticks([1,2,4,8,16,32,64,128,256,512,1024])
#plt.yticks(data)

"""
ax1.errorbar(x, y, xerr=asymmetric_error, fmt='o')
ax1.set_title('variable, asymmetric error')
ax1.set_yscale('log')
plt.show()"""
# Out:
# "\nax1.errorbar(x, y, xerr=asymmetric_error, fmt='o')\nax1.set_title('variable, asymmetric error')\nax1.set_yscale('log')\nplt.show()"

# %%
xerr
# Out:
# [0.280228400598,
#  0.268026576547,
#  0.265237043579,
#  0.264424639671,
#  0.263661433999,
#  0.264106872958,
#  0.267597827273,
#  0.260548798894,
#  0.263135273545,
#  0.263239009111,
#  0.262707187178]

# %%
plt.legend(bbox_to_anchor=(0.5, 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
fig, ax #= plt.subplots(figsize=(7, 4))
x=np.array([1,2,4,8,16,32,64,128,256,512,1024])
plt.xlabel('Block dimension')
plt.ylabel('Time (s)')
plt.title('FAST TRANSPOSE')
#errorbar(x,data,xerr)
#plt.plot(x,'r', label='bisector line')
plt.plot(x,data, label='1024') #
ax.errorbar(x, data, yerr=xerr, fmt='-o', label='fast transpose',color="darkblue")
#plt.semilogx(xvals)
#plt.semilogx(xvals, data, 'o')
#plt.axhline(y = mean1024)
#plt.axhline(y = mean2048)
#plt.axhline(y = mean4096)
marker_style = dict(linestyle=':', color='cornflowerblue', markersize=2)
plt.plot(x,data1, 'red',  label='2048',**marker_style)
#plt.plot(x,data1, 'red',  label='2048',markersize=10)
plt.plot(x,data2, 'darkviolet', label='4096',marker='$...$', markersize=4)
#plt.xticks([1,2,4,8,16,32,64,128,256,512,1024])
#plt.legend(('1024', '2048', '4096'))
#plt.plot(y,'r') #??????????????????
plt.legend()
plt.show()
