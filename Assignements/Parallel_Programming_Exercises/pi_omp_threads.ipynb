# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 200

# %%
data10M = []
with open('/home/nicole/P1.2_seed/Assignements/Parallel_Programming_Exercises/pi_omp_values') as datafile10M:
        for line in datafile10M:
            data10M.append(float(line))
print(data10M)
x = np.array([1,2,4,8,16,20])
plt.plot(x,data10M, '-o')
plt.ylabel('time(s)')
plt.title('pi_omp execution times on Ulysses, N=10e9')
plt.xticks(x,[1,2,4,8,16,20])
plt.xlabel('Number of processors')
# Out:
# [3.89, 1.98, 1.01, 0.54, 0.28, 0.33]
# Text(0.5,0,'Number of processors')
